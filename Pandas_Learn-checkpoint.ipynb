# %%
import pandas as pd    #import panda files

# %%
houseprice_train=pd.read_csv('houseprice_train.csv')   #makes Dataframes to be readable in pandas

# %%
houseprice_train     #Checking the dataframe
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
houseprice_train.index   #range of index
# Out:
# RangeIndex(start=0, stop=1460, step=1)

# %%
houseprice_train['Id']   #displays a column what we given along with index [also known as "series"]
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 1455    1456
# 1456    1457
# 1457    1458
# 1458    1459
# 1459    1460
# Name: Id, Length: 1460, dtype: int64

# %%
houseprice_train[['Id', 'MSZoning', 'LotArea', 'Street', 'Alley']]   #gives objeccts/values of assigned columns[DataFrame]
# Out:
#         Id MSZoning  LotArea Street Alley
# 0        1       RL     8450   Pave   NaN
# 1        2       RL     9600   Pave   NaN
# 2        3       RL    11250   Pave   NaN
# 3        4       RL     9550   Pave   NaN
# 4        5       RL    14260   Pave   NaN
# ...    ...      ...      ...    ...   ...
# 1455  1456       RL     7917   Pave   NaN
# 1456  1457       RL    13175   Pave   NaN
# 1457  1458       RL     9042   Pave   NaN
# 1458  1459       RL     9717   Pave   NaN
# 1459  1460       RL     9937   Pave   NaN
#
# [1460 rows x 5 columns]

# %%
type(houseprice_train)   #type of a variable
# Out:
# pandas.core.frame.DataFrame

# %%
type(houseprice_train['Id'])    #type of a column in main frame
# Out:
# pandas.core.series.Series

# %%
houseprice_train.value_counts()   #no value counts for a Dataframe
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-7f79d44e74dd> in <module>
# ----> 1 houseprice_train.value_counts()   #no value count for a Dataframe
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
houseprice_train['LotShape'].value_counts()    #value counts for a specified column
# Out:
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: LotShape, dtype: int64

# %%
houseprice_train.head()     #dispays the first 5 rows(default) in Dataframe
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
houseprice_train.head(10)   #displays  first 10 rows in dataframe
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
houseprice_train['Id'].head()    #displys first rows in specified column
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Id, dtype: int64

# %%
houseprice_train.tail()   #displays last 5 rows(default) of dataframe
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
houseprice_train.tail(12)    #displays last 12 rows of dataframe
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1448  1449          50       RL         70.0    11767   Pave   NaN      Reg
# 1449  1450         180       RM         21.0     1533   Pave   NaN      Reg
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# ...

# %%
houseprice_train['Alley'].tail(8)   # display last 8rows of a particular column
# Out:
# 1452     NaN
# 1453     NaN
# 1454    Pave
# 1455     NaN
# 1456     NaN
# 1457     NaN
# 1458     NaN
# 1459     NaN
# Name: Alley, dtype: object

# %%
houseprice_train.loc[5:10,:]   #gives 5to10 rows and all columns
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
#
#    LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 5          Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 6          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 7          Lvl    AllPub  ...        0    NaN    NaN        Shed     350
# 8          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 9          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
houseprice_train.loc[:9,'LotArea']   #gives untill 9th row with specified column
# Out:
# 0     8450
# 1     9600
# 2    11250
# 3     9550
# 4    14260
# 5    14115
# 6    10084
# 7    10382
# 8     6120
# 9     7420
# Name: LotArea, dtype: int64

# %%
houseprice_train.loc[2:5,['Alley','LotArea','Id']]   #gives 2to5 rows with mmultiple specified columns
# Out:
#   Alley  LotArea  Id
# 2   NaN    11250   3
# 3   NaN     9550   4
# 4   NaN    14260   5
# 5   NaN    14115   6

# %%
houseprice_train.loc[3:6,'Id':'LotArea']   #gives 3to6 rows and clomns from Id to LotArea
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea
# 3   4          70       RL         60.0     9550
# 4   5          60       RL         84.0    14260
# 5   6          50       RL         85.0    14115
# 6   7          20       RL         75.0    10084

# %%
houseprice_train.loc[houseprice_train.LotShape=='IR1']  #gives datafram having IR1 values in column LotShape
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1429  1430          20       RL          NaN    12546   Pave   NaN      IR1
# 1431  1432         120       RL          NaN     4928   Pave   NaN      IR1
# 1433  1434          60       RL         93.0    10261   Pave   NaN      IR1
# 1440  1441          70       RL         79.0    11526   Pave   NaN      IR1
# 1446  1447          20       RL          NaN    26142   Pave   NaN      IR1
#
# ...

# %%
houseprice_train.iloc[:5,:8]  #gives first 5rows and first 8columns
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1

# %%
houseprice_train.isnull()    #shows the value 0,NaN,null in the form of True in dataframe
# Out:
#          Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     False       False     False        False    False   False   True
# 1     False       False     False        False    False   False   True
# 2     False       False     False        False    False   False   True
# 3     False       False     False        False    False   False   True
# 4     False       False     False        False    False   False   True
# ...     ...         ...       ...          ...      ...     ...    ...
# 1455  False       False     False        False    False   False   True
# 1456  False       False     False        False    False   False   True
# 1457  False       False     False        False    False   False   True
# 1458  False       False     False        False    False   False   True
# 1459  False       False     False        False    False   False   True
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
pd.isnull(houseprice_train['Fence']) # gives you position of null values in the given column
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1455     True
# 1456    False
# 1457    False
# 1458     True
# 1459     True
# Name: Fence, Length: 1460, dtype: bool

# %%
a = None   #example for isnull
pd.isnull(a)
# Out:
# True

# %%
pd.isnull(houseprice_train)   #shows you null value of a datafram
# Out:
#          Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     False       False     False        False    False   False   True
# 1     False       False     False        False    False   False   True
# 2     False       False     False        False    False   False   True
# 3     False       False     False        False    False   False   True
# 4     False       False     False        False    False   False   True
# ...     ...         ...       ...          ...      ...     ...    ...
# 1455  False       False     False        False    False   False   True
# 1456  False       False     False        False    False   False   True
# 1457  False       False     False        False    False   False   True
# 1458  False       False     False        False    False   False   True
# 1459  False       False     False        False    False   False   True
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
type(houseprice_train) # check the type
# Out:
# pandas.core.frame.DataFrame

# %%
houseprice_train.dtypes # give type of all columns in dataframe
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
houseprice_train['Id'].astype('float') # cahnging type of a column from int to float
# Out:
# 0          1.0
# 1          2.0
# 2          3.0
# 3          4.0
# 4          5.0
#          ...
# 1455    1456.0
# 1456    1457.0
# 1457    1458.0
# 1458    1459.0
# 1459    1460.0
# Name: Id, Length: 1460, dtype: float64

# %%
houseprice_train.replace({'RL':'Sukesh'})  #can replace any values(or)objects in a dataframe
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60   Sukesh         65.0     8450   Pave   NaN      Reg
# 1        2          20   Sukesh         80.0     9600   Pave   NaN      Reg
# 2        3          60   Sukesh         68.0    11250   Pave   NaN      IR1
# 3        4          70   Sukesh         60.0     9550   Pave   NaN      IR1
# 4        5          60   Sukesh         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60   Sukesh         62.0     7917   Pave   NaN      Reg
# 1456  1457          20   Sukesh         85.0    13175   Pave   NaN      Reg
# 1457  1458          70   Sukesh         66.0     9042   Pave   NaN      Reg
# 1458  1459          20   Sukesh         68.0     9717   Pave   NaN      Reg
# 1459  1460          20   Sukesh         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
houseprice_train.replace({60:'Sukesh', 'Reg':'Krishna'})  #multiple replacements
# Out:
#         Id MSSubClass MSZoning LotFrontage  LotArea Street Alley LotShape  \
# 0        1     Sukesh       RL          65     8450   Pave   NaN  Krishna
# 1        2         20       RL          80     9600   Pave   NaN  Krishna
# 2        3     Sukesh       RL          68    11250   Pave   NaN      IR1
# 3        4         70       RL      Sukesh     9550   Pave   NaN      IR1
# 4        5     Sukesh       RL          84    14260   Pave   NaN      IR1
# ...    ...        ...      ...         ...      ...    ...   ...      ...
# 1455  1456     Sukesh       RL          62     7917   Pave   NaN  Krishna
# 1456  1457         20       RL          85    13175   Pave   NaN  Krishna
# 1457  1458         70       RL          66     9042   Pave   NaN  Krishna
# 1458  1459         20       RL          68     9717   Pave   NaN  Krishna
# 1459  1460         20       RL          75     9937   Pave   NaN  Krishna
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# ...

# %%
houseprice_train.rename(columns={'Id':'SUKESH', 'Alley':'VARMA'})   #rename columns in dataframe
# Out:
#       SUKESH  MSSubClass MSZoning  LotFrontage  LotArea Street VARMA LotShape  \
# 0          1          60       RL         65.0     8450   Pave   NaN      Reg
# 1          2          20       RL         80.0     9600   Pave   NaN      Reg
# 2          3          60       RL         68.0    11250   Pave   NaN      IR1
# 3          4          70       RL         60.0     9550   Pave   NaN      IR1
# 4          5          60       RL         84.0    14260   Pave   NaN      IR1
# ...      ...         ...      ...          ...      ...    ...   ...      ...
# 1455    1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456    1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457    1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458    1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459    1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
houseprice_train.rename(index={0:'S', 1:'U', 2:'K', 3:'E', 4:'S', 5:'H'}) #remane index in datafram
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# S        1          60       RL         65.0     8450   Pave   NaN      Reg
# U        2          20       RL         80.0     9600   Pave   NaN      Reg
# K        3          60       RL         68.0    11250   Pave   NaN      IR1
# E        4          70       RL         60.0     9550   Pave   NaN      IR1
# S        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
houseprice_train.dropna()  # eliminate the rows with null(or)0(or)NaN values
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# ...

# %%
houseprice_train.dropna(subset=['PoolQC'])  #eliminate the rows having null values in specified column
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 197    198          75       RL        174.0    25419   Pave   NaN      Reg
# 810    811          20       RL         78.0    10140   Pave   NaN      Reg
# 1170  1171          80       RL         76.0     9880   Pave   NaN      Reg
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
# 1386  1387          60       RL         80.0    16692   Pave   NaN      IR1
# 1423  1424          80       RL          NaN    19690   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 197          Lvl    AllPub  ...      512     Ex  GdPrv         NaN       0
# 810          Lvl    AllPub  ...      648     Fa  GdPrv         NaN       0
# 1170         Lvl    AllPub  ...      576     Gd  GdPrv         NaN       0
# ...

# %%
houseprice_train.dropna(subset=['PoolQC', 'Fence']) #eleminate  rows having null values in multiple columns
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 197    198          75       RL        174.0    25419   Pave   NaN      Reg
# 810    811          20       RL         78.0    10140   Pave   NaN      Reg
# 1170  1171          80       RL         76.0     9880   Pave   NaN      Reg
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
# 1386  1387          60       RL         80.0    16692   Pave   NaN      IR1
# 1423  1424          80       RL          NaN    19690   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 197          Lvl    AllPub  ...      512     Ex  GdPrv         NaN       0
# 810          Lvl    AllPub  ...      648     Fa  GdPrv         NaN       0
# 1170         Lvl    AllPub  ...      576     Gd  GdPrv         NaN       0
# 1182         Lvl    AllPub  ...      555     Ex  MnPrv         NaN       0
# ...

# %%
houseprice_train.sort_values(by=['MSSubClass']) #gives ascending(default) order values of a specified column
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
# 888    889          20       RL         95.0    15865   Pave   NaN      IR1
# 889    890          20       RL        128.0    12160   Pave   NaN      Reg
# 892    893          20       RL         70.0     8414   Pave   NaN      Reg
# 893    894          20       RL          NaN    13284   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 520    521         190       RL         60.0    10800   Pave  Grvl      Reg
# 1266  1267         190       RM         60.0    10120   Pave   NaN      IR1
# 48      49         190       RM         33.0     4456   Pave   NaN      Reg
# 1062  1063         190       RM         85.0    13600   Pave  Grvl      Reg
# 861    862         190       RL         75.0    11625   Pave   NaN      Reg
#
# ...

# %%
houseprice_train.sort_values(by=['MSSubClass', 'LotArea'], ascending=False)  #gives descending order values of a specified column
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 335    336         190       RL          NaN   164660   Grvl   NaN      IR1
# 411    412         190       RL        100.0    34650   Pave   NaN      Reg
# 1190  1191         190       RL          NaN    32463   Pave   NaN      Reg
# 300    301         190       RL         90.0    15750   Pave   NaN      Reg
# 1062  1063         190       RM         85.0    13600   Pave  Grvl      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 323    324          20       RM         49.0     5820   Pave   NaN      Reg
# 1114  1115          20       RL         90.0     5400   Pave   NaN      Reg
# 533    534          20       RL         50.0     5000   Pave   NaN      Reg
# 412    413          20       FV          NaN     4403   Pave   NaN      IR2
# 982    983          20       RL         43.0     3182   Pave   NaN      Reg
#
# ...

# %%
houseprice_train.sum() #sum of all columns in dataframe
# Out:
# Id                                                         1066530
# MSSubClass                                                   83070
# MSZoning         RLRLRLRLRLRLRLRLRMRLRLRLRLRLRLRMRLRLRLRLRLRMRL...
# LotFrontage                                                  84130
# LotArea                                                   15354569
#                                        ...
# MoSold                                                        9230
# YrSold                                                     2931411
# SaleType         WDWDWDWDWDWDWDWDWDWDWDNewWDNewWDWDWDWDWDCODNew...
# SaleCondition    NormalNormalNormalAbnormlNormalNormalNormalNor...
# SalePrice                                                264144946
# Length: 65, dtype: object

# %%
houseprice_train['MSSubClass'].sum() #gives sum of specified column
# Out:
# 83070

# %%
houseprice_train.columns   #gives column names in dataframe
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
houseprice_train.shape  #shows no., of rows and columns in dataframe
# Out:
# (1460, 81)

# %%
houseprice_train.mean()  #gives average of all culomn in dataframe
# Out:
# Id                  730.500000
# MSSubClass           56.897260
# LotFrontage          70.049958
# LotArea           10516.828082
# OverallQual           6.099315
# OverallCond           5.575342
# YearBuilt          1971.267808
# YearRemodAdd       1984.865753
# MasVnrArea          103.685262
# BsmtFinSF1          443.639726
# BsmtFinSF2           46.549315
# BsmtUnfSF           567.240411
# TotalBsmtSF        1057.429452
# 1stFlrSF           1162.626712
# 2ndFlrSF            346.992466
# LowQualFinSF          5.844521
# GrLivArea          1515.463699
# BsmtFullBath          0.425342
# BsmtHalfBath          0.057534
# FullBath              1.565068
# HalfBath              0.382877
# BedroomAbvGr          2.866438
# KitchenAbvGr          1.046575
# TotRmsAbvGrd          6.517808
# Fireplaces            0.613014
# GarageYrBlt        1978.506164
# GarageCars            1.767123
# GarageArea          472.980137
# WoodDeckSF           94.244521
# OpenPorchSF          46.660274
# ...

# %%
houseprice_train["MSSubClass"].mean()  #average of a given column
# Out:
# 56.897260273972606

# %%
houseprice_train.drop(index=[0,2,4,6,8,10])   #deletes the index rows that specified in datafram
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
houseprice_train.drop(columns=['Id', 'MSZoning'])  #deletes the columns that specified in dataframe
# Out:
#       MSSubClass  LotFrontage  LotArea Street Alley LotShape LandContour  \
# 0             60         65.0     8450   Pave   NaN      Reg         Lvl
# 1             20         80.0     9600   Pave   NaN      Reg         Lvl
# 2             60         68.0    11250   Pave   NaN      IR1         Lvl
# 3             70         60.0     9550   Pave   NaN      IR1         Lvl
# 4             60         84.0    14260   Pave   NaN      IR1         Lvl
# ...          ...          ...      ...    ...   ...      ...         ...
# 1455          60         62.0     7917   Pave   NaN      Reg         Lvl
# 1456          20         85.0    13175   Pave   NaN      Reg         Lvl
# 1457          70         66.0     9042   Pave   NaN      Reg         Lvl
# 1458          20         68.0     9717   Pave   NaN      Reg         Lvl
# 1459          20         75.0     9937   Pave   NaN      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
houseprice_train.corr()  #correlation of a values between columns dataframe
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
houseprice_train.describe()   #gives diff arithmetic operations for each column in dataframe
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
houseprice_train.groupby(["MSZoning","Alley"]).mean()  #Groups specified columns having common values(or)object and applies the arithmetic operation given
# Out:
#                         Id  MSSubClass  LotFrontage       LotArea  \
# MSZoning Alley
# C (all)  Pave   371.500000   60.000000    58.000000   8606.000000
# FV       Pave   736.375000  125.833333    39.166667   4166.666667
# RH       Pave   659.000000  120.000000    57.500000   7698.000000
# RL       Grvl   889.928571   62.857143    57.642857  10003.714286
#          Pave   708.166667   57.500000    58.500000  10286.666667
# RM       Grvl   676.000000   64.305556    63.484848   8515.916667
#          Pave   828.428571   70.000000    59.285714   7107.142857
#
#                 OverallQual  OverallCond    YearBuilt  YearRemodAdd  \
# MSZoning Alley
# C (all)  Pave      4.000000     5.500000  1910.000000   1950.000000
# FV       Pave      6.916667     5.000000  2003.708333   2004.125000
# RH       Pave      5.500000     6.000000  1923.000000   1997.500000
# RL       Grvl      4.500000     6.000000  1920.214286   1972.285714
# ...

# %%
houseprice_train.groupby(["MSZoning","Alley"]).sum()
# Out:
#                    Id  MSSubClass  LotFrontage  LotArea  OverallQual  \
# MSZoning Alley
# C (all)  Pave     743         120        116.0    17212            8
# FV       Pave   17673        3020        940.0   100000          166
# RH       Pave    1318         240        115.0    15396           11
# RL       Grvl   12459         880        807.0   140052           63
#          Pave    4249         345        234.0    61720           35
# RM       Grvl   24336        2315       2095.0   306573          196
#          Pave    5799         490        415.0    49750           43
#
#                 OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# MSZoning Alley
# C (all)  Pave            11       3820          3900         0.0           0
# FV       Pave           120      48089         48099      5327.0        6927
# RH       Pave            12       3846          3995         0.0         438
# ...

# %%
houseprice_train.column # gives all column names in a dataframe
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
houseprice_train.groupby(["MSZoning","Alley"]).count()
# Out:
#                 Id  MSSubClass  LotFrontage  LotArea  Street  LotShape  \
# MSZoning Alley
# C (all)  Pave    2           2            2        2       2         2
# FV       Pave   24          24           24       24      24        24
# RH       Pave    2           2            2        2       2         2
# RL       Grvl   14          14           14       14      14        14
#          Pave    6           6            4        6       6         6
# RM       Grvl   36          36           33       36      36        36
#          Pave    7           7            7        7       7         7
#
#                 LandContour  Utilities  LotConfig  LandSlope  ...  PoolArea  \
# MSZoning Alley                                                ...
# C (all)  Pave             2          2          2          2  ...         2
# FV       Pave            24         24         24         24  ...        24
# RH       Pave             2          2          2          2  ...         2
# ...

# %%
houseprice_train.to_csv(r"py test\PANDAS_test_commands.csv")
